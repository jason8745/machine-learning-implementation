# %% [markdown]
# # 1.資料前處理,將train和test合併處理

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '0.23.0'

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df_train = pd.read_csv('train.csv')

# %%
df_test = pd.read_csv('test.csv')

# %%
#df_train.head()

# %%
#df_train.columns

# %%
#將目標變數暫且分離,並且將其正規化
train_Y = np.log1p(df_train['total_price'])

# %%
#保留test and train的id
train_ID = df_train['building_id']
test_ID = df_test['building_id']

# %%
#將id drop掉
#Now drop the  'Id' colum since it's unnecessary for  the prediction process.
df_train.drop("building_id", axis = 1, inplace = True)
df_test.drop("building_id", axis = 1, inplace = True)

# %%
ntrain = df_train.shape[0]
ntest = df_test.shape[0]

# %%
#將salepricedrop掉
df_train.drop('total_price',axis=1,inplace = True)

# %%
df = pd.concat((df_train, df_test)).reset_index(drop=True)

# %%
#df.head()

# %%
df.shape
# Out:
# (70000, 233)

# %% [markdown]
# # 2.資料清理

# %%
#missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                        Total   Percent
# parking_area           66397  0.948529
# parking_price          53775  0.768214
# txn_floor              18541  0.264871
# village_income_median   1326  0.018943
# IV_250                     0  0.000000
# IV_100                     0  0.000000
# IV_index_50                0  0.000000
# IV_50                      0  0.000000
# IV_10                      0  0.000000
# III_index_1000             0  0.000000
# IV_500                     0  0.000000
# IV_index_500               0  0.000000
# III_MIN                    0  0.000000
# III_index_10000            0  0.000000
# III_10000                  0  0.000000
# III_index_5000             0  0.000000
# III_5000                   0  0.000000
# XIV_MIN                    0  0.000000
# III_1000                   0  0.000000
# IV_index_1000              0  0.000000

# %% [markdown]
# 我們可以發現,只有四個屬性資料有遺失值,我們將觀察這四項遺失值的相關資訊,以做出適當的遺失值處理

# %% [markdown]
# 1. parking area

# %% [markdown]
# 假設一 填補遺失值

# %%
#plt.plot(df['parking_area'])

# %%
#df['parking_area'].describe()

# %%
#計算相關變數,找出和parking_area最相關的欄位
#corr = df.corr()

# %%
#corr.parking_area.sort_values(ascending=False)[:5]

# %% [markdown]
# 假設二 遺失值及代表沒有車位,將na填上0

# %%
df['parking_area'].fillna(0,inplace=True)

# %% [markdown]
# 2.parking_price

# %%
#df['parking_price'].describe()

# %%
#先假設遺失值為0
df['parking_price'].fillna(0,inplace=True)

# %% [markdown]
# 3.txn_floor

# %%
#Nan可能是透天或是沒有樓層,所以我們需要特別去判斷,Nan的價格如何
from collections import Counter
df['txn_floor'].fillna(0,inplace =True)
#Counter(df['txn_floor'])

# %% [markdown]
# 4.village_income_median

# %%
#一樣透過corr判斷哪一個影響median最多
#corr.village_income_median.sort_values(ascending=False)[:5]

# %%
#可以看得出學歷是對其影響最大的,所以我們應該要參考學歷來做遺失值的填補
#median_df = df.groupby(['master_rate'])['village_income_median'];median_df

# %%
#暫時用所有的median去補
df['village_income_median'].fillna(df['village_income_median'].median(),inplace=True)

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(5)
# Out:
#           Total  Percent
# XIV_MIN       0      0.0
# III_1000      0      0.0
# IV_500        0      0.0
# IV_250        0      0.0
# IV_100        0      0.0

# %% [markdown]
# 到此為止遺失值都處理完,第一次做我們先找個baseline之後再優化,先求有再求好

# %% [markdown]
# # 類別資料處理 LabelEncoder and 獨熱

# %% [markdown]
# 大問題,有許多原本應該被視為是類別的資料現在被視為是連續資料,因此我們需要做出更改

# %%
object_col=['txn_floor','building_material','city','town','village','building_type',\
           'building_use','parking_way'
           ]

# %%
#將原本是object的做轉型
for c in object_col:
    df.loc[:,c]=df[c].astype('str')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Columns: 233 entries, building_material to XIV_MIN
# dtypes: float64(35), int64(190), object(8)
# memory usage: 124.4+ MB

# %% [markdown]
# # 經緯度轉化

# %%
sns.jointplot(df.lon,df.lat)
# Out:
# C:\Users\a0970\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\a0970\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df.lon=df.lon/119.66*122

# %%
df.lat=df.lat+62

# %%
sns.jointplot(df.lon,df.lat)
# Out:
# C:\Users\a0970\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\a0970\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# dft嘗試區

# %%
dft=df[:ntrain]
dft.loc[:,'price']=train_Y
# Out:
# C:\Users\a0970\Anaconda3\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\a0970\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x=pd.cut(dft['price'],4)
dft['segment']=x
# Out:
# C:\Users\a0970\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dft.lon=dft.lon/119.66*122
dft.lat=dft.lat+62
# Out:
# C:\Users\a0970\Anaconda3\lib\site-packages\pandas\core\generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
##在預測的時候應該要加重市區的權重,增加一個feature
sns.lmplot(x='lon', y='lat', hue='segment', data=dft, fit_reg=False)

# %%
#經過觀測,可以將此新feature加入
x=pd.cut(dft['town_population_density'],4)
dft['region']=x
sns.lmplot(x='lon', y='lat', hue='region', data=dft, fit_reg=False)
# Out:
# C:\Users\a0970\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#經過觀測,可以將此新feature加入
#x=pd.cut(dft['town_population_density'],4)
#dft[:,'region']=x
sns.lmplot(x='lon', y='lat', hue='doc_rate', data=dft, fit_reg=False)

# %%
sns.lmplot(x='lon', y='lat', hue='master_rate', data=dft, fit_reg=False)

# %%
#里民收入
#經過觀測,可以將此新feature加入
x=pd.cut(dft['village_income_median'],5)
dft['income']=x
sns.lmplot(x='lon', y='lat', hue='income', data=dft, fit_reg=False)
# Out:
# C:\Users\a0970\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
x=pd.cut(dft['doc_rate'],4)
dft['doc_split']=x
sns.lmplot(x='lon', y='lat', hue='doc_split', data=dft, fit_reg=False)

# %%
x=pd.cut(dft['master_rate'],4)
dft['master_split']=x
sns.lmplot(x='lon', y='lat', hue='master_split', data=dft, fit_reg=False)

# %%
x=pd.cut(dft['bachelor_rate'],3)
dft['bachelor_split']=x
sns.lmplot(x='lon', y='lat', hue='bachelor_split', data=dft, fit_reg=False)

# %%
x=pd.cut(dft['highschool_rate'],3)
dft['highschool_split']=x
sns.lmplot(x='lon', y='lat', hue='highschool_split', data=dft, fit_reg=False)

# %%
x=pd.cut(dft['jobschool_rate'],4)
dft['jobschool_split']=x
sns.lmplot(x='lon', y='lat', hue='jobschool_split', data=dft, fit_reg=False)

# %%
x=pd.cut(dft['junior_rate'],3)
dft['junior_split']=x
sns.lmplot(x='lon', y='lat', hue='junior_split', data=dft, fit_reg=False)

# %%
x=pd.cut(dft['elementary_rate'],7)
dft['elementary_split']=x
sns.lmplot(x='lon', y='lat', hue='elementary_split', data=dft, fit_reg=False)

# %%
x=pd.cut(dft['born_rate'],6)
dft['born_split']=x
sns.lmplot(x='lon', y='lat', hue='born_split', data=dft, fit_reg=False)

# %%
x=pd.cut(dft['death_rate'],7)
dft['death_split']=x
sns.lmplot(x='lon', y='lat', hue='death_split', data=dft, fit_reg=False)

# %%
x=pd.cut(dft['marriage_rate'],7)
dft['marriage_split']=x
sns.lmplot(x='lon', y='lat', hue='marriage_split', data=dft, fit_reg=False)

# %%
x=pd.cut(dft['divorce_rate'],7)
dft['divorce_split']=x
sns.lmplot(x='lon', y='lat', hue='divorce_split', data=dft, fit_reg=False)

# %% [markdown]
# try to add new feature

# %%
#restart
df_test=df.copy()

# %%
#try to transform the density into discrete
df_test.loc[:,'density']=pd.cut(df_test['town_population_density'],4)
df_test=df_test.drop('town_population_density',axis=1)

# %%
#移除掉這兩個欄位,因為密度是其合成,可能會有較高的共線性
df_test=df_test.drop(['town_area','town_population'],axis=1)

# %%
#try to transform the median_income into discrete
df_test.loc[:,'income']=pd.cut(df_test['village_income_median'],5)
df_test=df_test.drop('village_income_median',axis=1)

# %%
#try to transform the doc_rate into discrete
df_test.loc[:,'doc_split']=pd.cut(df_test['doc_rate'],4)
df_test=df_test.drop('doc_rate',axis=1)

# %%
#try to transform the bachelor_rate into discrete
df_test.loc[:,'bachelor_split']=pd.cut(df_test['bachelor_rate'],3)
df_test=df_test.drop('bachelor_rate',axis=1)

# %%
#try to transform the highschool_rate into discrete
df_test.loc[:,'highschool_split']=pd.cut(df_test['highschool_rate'],3)
df_test=df_test.drop('highschool_rate',axis=1)

# %%
#try to transform the jobschool_rate into discrete
df_test.loc[:,'jobschool_split']=pd.cut(df_test['jobschool_rate'],4)
df_test=df_test.drop('jobschool_rate',axis=1)

# %%
#try to transform the junior_rate into discrete
df_test.loc[:,'junior_split']=pd.cut(df_test['junior_rate'],3)
df_test=df_test.drop('junior_rate',axis=1)

# %%
#try to transform the elementary_rate into discrete
df_test.loc[:,'elementary_split']=pd.cut(df_test['elementary_rate'],7)
df_test=df_test.drop('elementary_rate',axis=1)

# %%
#try to transform the born_rate into discrete
df_test.loc[:,'born_split']=pd.cut(df_test['born_rate'],6)
df_test=df_test.drop('born_rate',axis=1)

# %%
#try to transform the death_rate into discrete
df_test.loc[:,'death_split']=pd.cut(df_test['death_rate'],7)
df_test=df_test.drop('death_rate',axis=1)

# %%
#try to transform the marriage_rate into discrete
df_test.loc[:,'marriage_split']=pd.cut(df_test['marriage_rate'],7)
df_test=df_test.drop('marriage_rate',axis=1)

# %%
#try to transform the divorce_rate into discrete
df_test.loc[:,'divorce_split']=pd.cut(df_test['divorce_rate'],7)
df_test=df_test.drop('divorce_rate',axis=1)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Columns: 231 entries, building_material to divorce_split
# dtypes: category(12), float64(21), int64(190), object(8)
# memory usage: 117.8+ MB

# %%
df_test.dtypes
# Out:
# building_material         object
# city                      object
# txn_dt                     int64
# total_floor                int64
# building_type             object
# building_use              object
# building_complete_dt       int64
# parking_way               object
# parking_area             float64
# parking_price            float64
# txn_floor                 object
# land_area                float64
# building_area            float64
# town                      object
# lat                      float64
# lon                      float64
# master_rate              float64
# village                   object
# N_50                       int64
# N_500                      int64
# N_1000                     int64
# N_5000                     int64
# N_10000                    int64
# I_10                       int64
# I_50                       int64
# I_index_50                 int64
# I_100                      int64
# I_250                      int64
# ...

# %% [markdown]
# 接著有兩種做法,第一種是使用one-hot encoding全做,第二種是categories的要做排序型的編碼

# %% [markdown]
# 將categories的做排序

# %%
cat_features = []
for dtype, feature in zip(df_test.dtypes, df_test.columns):
    if dtype ==pd.Categorical:
        cat_features.append(feature)

# %%
#one-hot Encoding
df_temp = pd.get_dummies(df_test)

# %% [markdown]
# end

# %%
#one-hot Encoding
df_temp = pd.get_dummies(df)

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Columns: 3500 entries, txn_dt to divorce_split_(2.647, 2.78]
# dtypes: float64(21), int64(190), uint8(3289)
# memory usage: 332.3 MB

# %%
df_temp.head()
# Out:
#    txn_dt  total_floor  building_complete_dt  parking_area  parking_price  \
# 0   18674            4                  6271           0.0       0.000000
# 1   18800            5                  7885           0.0       0.000000
# 2   19289            4                  6028           0.0       0.000000
# 3   20385           24                 18325           0.0   81138.889762
# 4   20657            2                  6880           0.0       0.000000
#
#    land_area  building_area    lat         lon  master_rate  \
# 0  18.144460       3.418175  22.86  119.369547     0.047944
# 1  11.387227       4.041309  24.34  121.612569     0.048779
# 2  21.426802       5.584279  24.33  121.622764     0.048779
# 3  11.387227      13.563031  22.87  119.379743     0.047944
# 4  61.306524       4.688108  22.76  119.481698     0.047944
#
#               ...               marriage_split_(6.064, 6.283]  \
# 0             ...                                           0
# ...

# %%
#將train資料和test資料分開
train = df_temp[:ntrain]
test = df_temp[ntrain:]

# %% [markdown]
# # 模型嘗試

# %%
from sklearn import cross_validation, grid_search, metrics, ensemble
import xgboost as xgb
# Out:
# C:\Users\a0970\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\a0970\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
train_data, test_data, train_labels, test_labels = cross_validation.train_test_split(train,train_Y, test_size = 0.2)

# %%
"""#跑好久
model = xgb.XGBRegressor()
# Create parameters grid

parameters_grid = { 'learning_rate' : [0.1, 0.2, 0.5], 'max_depth' : [5, 10, 15], 'n_estimators' : [150, 250, 300], 'min_child_weight' : [3, 5, 10] }

# Strategy of cross validation

#cv = cross_validation.StratifiedShuffleSplit(train_labels, n_iter = 3, test_size = 0.3)

# Create Grid search Strategy

grid_cv = grid_search.RandomizedSearchCV(model, parameters_grid, scoring = 'neg_mean_absolute_error', cv = 3)

# Fit model by Grid

grid_cv.fit(train_data, train_labels)
grid_cv.best_estimator_
"""
# Out:
# C:\Users\a0970\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\a0970\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-123e4f55127e> in <module>()
#      14 # Fit model by Grid
#      15
# ---> 16 grid_cv.fit(train_data, train_labels)
#      17 grid_cv.best_estimator_
#
# ~\Anaconda3\lib\site-packages\sklearn\grid_search.py in fit(self, X, y)
#    1044                                           self.n_iter,
#    1045                                           random_state=self.random_state)
# ...

# %%
model_xgb = xgb.XGBRegressor(n_estimators=300, max_depth=10, learning_rate=0.01,min_child_weight=10)

# %%
model_xgb.fit(train_data, train_labels)
# Out:
# C:\Users\a0970\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-026a8e7bc0db> in <module>()
# ----> 1 model_xgb.fit(train_data, train_labels)
#
# ~\Anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     340                                    missing=self.missing, nthread=self.n_jobs)
#     341         else:
# --> 342             trainDmatrix = DMatrix(X, label=y, missing=self.missing, nthread=self.n_jobs)
#     343
#     344         evals_result = {}
#
# ...

# %%
pred_xgb = model_xgb.predict(test)

# %% [markdown]
# 將資料轉回來價格

# %%
import math

# %%
list_price = []
for y in list(pred):
    list_price.append(pow(np.e,y))

# %%
test_ans = pd.DataFrame({'Id': Id, 'SalePrice': pred_xgb})
